# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from numpy import pi as π

# %%
from scipy.stats import truncexpon

# %%
x = 3*np.random.normal(size=10000) + 3

# %%
def normal(x,λ,σ):
    return 1.0/np.sqrt(2*π*σ**2)*np.exp(-(x-λ)**2/(2*σ**2))

# %%
tx = np.linspace(-10,10,1000)
plt.plot(tx,normal(tx,3,3))
plt.hist(x, density=True, bins=50)
# Out:
# (array([0.00078971, 0.00039485, 0.00059228, 0.00098714, 0.00138199,
#         0.00375112, 0.00671253, 0.00710739, 0.01164822, 0.02092731,
#         0.03316782, 0.03277296, 0.04047264, 0.05133115, 0.06238709,
#         0.0754173 , 0.10108288, 0.10147773, 0.12556389, 0.12793302,
#         0.13622497, 0.13346099, 0.13247385, 0.12418189, 0.11253367,
#         0.10049059, 0.09298835, 0.07423274, 0.06258452, 0.05133115,
#         0.04145977, 0.0337601 , 0.02625786, 0.01539934, 0.01125337,
#         0.00651511, 0.00414598, 0.00335627, 0.00276398, 0.00098714,
#         0.00118456, 0.        , 0.00039485, 0.00019743, 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.00019743]),
#  array([-7.83968218, -7.33316711, -6.82665204, -6.32013698, -5.81362191,
#         -5.30710684, -4.80059177, -4.2940767 , -3.78756164, -3.28104657,
#         -2.7745315 , -2.26801643, -1.76150136, -1.2549863 , -0.74847123,
#         -0.24195616,  0.26455891,  0.77107398,  1.27758904,  1.78410411,
#          2.29061918,  2.79713425,  3.30364932,  3.81016438,  4.31667945,
#          4.82319452,  5.32970959,  5.83622466,  6.34273972,  6.84925479,
#          7.35576986,  7.86228493,  8.3688    ,  8.87531506,  9.38183013,
#          9.8883452 , 10.39486027, 10.90137534, 11.4078904 , 11.91440547,
#         12.42092054, 12.92743561, 13.43395068, 13.94046574, 14.44698081,
#         14.95349588, 15.46001095, 15.96652602, 16.47304108, 16.97955615,
#         17.48607122]),
#  <a list of 50 Patch objects>)

# %%
def trunc_exp(x,b,scale):
    return np.exp(-x/scale)/(1.0-np.exp(-b/scale))/scale

# %%
b = 2
scale = 1.5
r = truncexpon.rvs(b=b/scale,scale=scale,size=10000)
rp = truncexpon.rvs(b=b,size=10000)

tr = np.linspace(0,b,1000)

# %%
plt.plot(tr,trunc_exp(tr,b,scale))
plt.hist(r, density=True, bins=50);
#plt.yscale('log')
# Out:
# (array([0.86053694, 0.82801665, 0.82051197, 0.89055567, 0.76797919,
#         0.81050572, 0.69543392, 0.71294485, 0.66291363, 0.7354589 ,
#         0.71544641, 0.70794173, 0.72295109, 0.72795421, 0.65290739,
#         0.62789178, 0.47529657, 0.6203871 , 0.58536524, 0.53533403,
#         0.50781686, 0.50281374, 0.56535276, 0.45028096, 0.45778564,
#         0.38774194, 0.41025598, 0.41776067, 0.37023101, 0.41776067,
#         0.37273257, 0.36522789, 0.42526535, 0.36522789, 0.38023725,
#         0.40525286, 0.29768574, 0.35021852, 0.38023725, 0.27767326,
#         0.32019979, 0.28017482, 0.29018106, 0.24765453, 0.31519667,
#         0.26766701, 0.27016857, 0.2876795 , 0.23764828, 0.23514672]),
#  array([8.56547541e-04, 4.08315891e-02, 8.08066307e-02, 1.20781672e-01,
#         1.60756714e-01, 2.00731755e-01, 2.40706797e-01, 2.80681839e-01,
#         3.20656880e-01, 3.60631922e-01, 4.00606963e-01, 4.40582005e-01,
#         4.80557046e-01, 5.20532088e-01, 5.60507130e-01, 6.00482171e-01,
#         6.40457213e-01, 6.80432254e-01, 7.20407296e-01, 7.60382337e-01,
#         8.00357379e-01, 8.40332420e-01, 8.80307462e-01, 9.20282504e-01,
#         9.60257545e-01, 1.00023259e+00, 1.04020763e+00, 1.08018267e+00,
#         1.12015771e+00, 1.16013275e+00, 1.20010779e+00, 1.24008284e+00,
#         1.28005788e+00, 1.32003292e+00, 1.36000796e+00, 1.39998300e+00,
#         1.43995804e+00, 1.47993309e+00, 1.51990813e+00, 1.55988317e+00,
#         1.59985821e+00, 1.63983325e+00, 1.67980829e+00, 1.71978334e+00,
#         1.75975838e+00, 1.79973342e+00, 1.83970846e+00, 1.87968350e+00,
#         1.91965854e+00, 1.95963358e+00, 1.99960863e+00]),
#  <a list of 50 Patch objects>)
