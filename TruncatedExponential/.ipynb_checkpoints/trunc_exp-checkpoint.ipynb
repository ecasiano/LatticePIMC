# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from numpy import pi as π

# %%
from scipy.stats import truncexpon

# %%
x = 3*np.random.normal(size=10000) + 3

# %%
def normal(x,λ,σ):
    return 1.0/np.sqrt(2*π*σ**2)*np.exp(-(x-λ)**2/(2*σ**2))

# %%
tx = np.linspace(-10,10,1000)
plt.plot(tx,normal(tx,3,3))
plt.hist(x, density=True, bins=50)
# Out:
# (array([0.00021038, 0.        , 0.        , 0.        , 0.00063113,
#         0.00063113, 0.00126226, 0.00126226, 0.00252453, 0.00252453,
#         0.00546981, 0.01009811, 0.01220189, 0.01661981, 0.02124811,
#         0.03176698, 0.03555377, 0.04901792, 0.06206132, 0.07805   ,
#         0.09256603, 0.10371603, 0.11633867, 0.11696981, 0.12938207,
#         0.13695566, 0.12454339, 0.13401037, 0.12328113, 0.11696981,
#         0.11381415, 0.08646509, 0.0761566 , 0.06774151, 0.05575   ,
#         0.04523113, 0.03345   , 0.03218773, 0.01872358, 0.01746132,
#         0.01093962, 0.00694245, 0.00378679, 0.00589057, 0.00105189,
#         0.00063113, 0.00105189, 0.00021038, 0.00021038, 0.00021038]),
#  array([-9.41765812, -8.94232178, -8.46698544, -7.99164909, -7.51631275,
#         -7.04097641, -6.56564007, -6.09030373, -5.61496739, -5.13963105,
#         -4.66429471, -4.18895837, -3.71362203, -3.23828569, -2.76294935,
#         -2.287613  , -1.81227666, -1.33694032, -0.86160398, -0.38626764,
#          0.0890687 ,  0.56440504,  1.03974138,  1.51507772,  1.99041406,
#          2.4657504 ,  2.94108675,  3.41642309,  3.89175943,  4.36709577,
#          4.84243211,  5.31776845,  5.79310479,  6.26844113,  6.74377747,
#          7.21911381,  7.69445015,  8.16978649,  8.64512284,  9.12045918,
#          9.59579552, 10.07113186, 10.5464682 , 11.02180454, 11.49714088,
#         11.97247722, 12.44781356, 12.9231499 , 13.39848624, 13.87382258,
#         14.34915893]),
#  <a list of 50 Patch objects>)

# %%
def trunc_exp(x,b,scale):
    return np.exp(-x/scale)/(1.0-np.exp(-b))/scale

# %%
b = 2
scale = 1.5
r = truncexpon.rvs(b=b/scale,scale=scale,size=10000)
rp = truncexpon.rvs(b=b,size=10000)

tr = np.linspace(0,b,1000)

# %%
#plt.plot(tr,trunc_exp(tr,b,scale))
plt.hist(r, density=True, bins=50)
#plt.yscale('log')
# Out:
# (array([0.90006592, 0.91006665, 0.86256317, 0.8575628 , 0.88256464,
#         0.78005713, 0.73505383, 0.76005566, 0.73755402, 0.67504944,
#         0.77255658, 0.67254926, 0.60004395, 0.59754376, 0.56754156,
#         0.59004321, 0.58004248, 0.56504138, 0.61004468, 0.55504065,
#         0.48503552, 0.51253754, 0.45753351, 0.48253534, 0.49003589,
#         0.43253168, 0.44503259, 0.42253094, 0.42753131, 0.39002856,
#         0.39502893, 0.37502747, 0.41003003, 0.37752765, 0.35002563,
#         0.3700271 , 0.33502454, 0.29002124, 0.28752106, 0.3250238 ,
#         0.31752325, 0.29502161, 0.27502014, 0.26751959, 0.28752106,
#         0.31752325, 0.27001978, 0.23501721, 0.23251703, 0.23251703]),
#  array([5.73657055e-05, 4.00544363e-02, 8.00515068e-02, 1.20048577e-01,
#         1.60045648e-01, 2.00042718e-01, 2.40039789e-01, 2.80036860e-01,
#         3.20033930e-01, 3.60031001e-01, 4.00028071e-01, 4.40025142e-01,
#         4.80022212e-01, 5.20019283e-01, 5.60016353e-01, 6.00013424e-01,
#         6.40010494e-01, 6.80007565e-01, 7.20004636e-01, 7.60001706e-01,
#         7.99998777e-01, 8.39995847e-01, 8.79992918e-01, 9.19989988e-01,
#         9.59987059e-01, 9.99984129e-01, 1.03998120e+00, 1.07997827e+00,
#         1.11997534e+00, 1.15997241e+00, 1.19996948e+00, 1.23996655e+00,
#         1.27996362e+00, 1.31996069e+00, 1.35995776e+00, 1.39995483e+00,
#         1.43995191e+00, 1.47994898e+00, 1.51994605e+00, 1.55994312e+00,
#         1.59994019e+00, 1.63993726e+00, 1.67993433e+00, 1.71993140e+00,
#         1.75992847e+00, 1.79992554e+00, 1.83992261e+00, 1.87991968e+00,
#         1.91991675e+00, 1.95991382e+00, 1.99991089e+00]),
#  <a list of 50 Patch objects>)
