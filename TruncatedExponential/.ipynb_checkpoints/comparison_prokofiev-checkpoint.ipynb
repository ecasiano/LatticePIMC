# %% [markdown]
# ### Comparison with distribution from Prokof'ev slides

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import truncexpon
from scipy.integrate import quad, simps
from math import e

# %%
# Truncated exponential distribution based on Prokof'ev slides
def p(tau,loc,b,dV):
    return dV*e**(-dV*(tau-loc))/(1-e**(-dV*b))

# %%
loc = 0
b = 5
x = np.linspace(loc,loc+b,25)
dV = 0.6 #scale

# scipy.stats.truncexpon()
b = xmax-xmin
loc = xmin
scale = 1/dV
pdf = truncexpon.pdf(-x+b,b=b/scale,loc=loc,scale=scale)
B = simps(pdf,x)
print(B)
print(1-e**(-dV*b))
dV

# Prokof'ev
y = p(-x+b,loc,b,dV)
A = simps(y,x)
print(A)
plt.plot(x,y,ls='-',lw=4)
plt.plot(x,pdf,marker='*',ms=5)
# Out:
# 1.0000013538179902
# 0.950212931632136
# 1.0000013538179904
